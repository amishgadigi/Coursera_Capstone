# %%
from geopy.geocoders import Nominatim

# %%
import pandas as pd
import numpy as np
import requests

# %%
address = 'Domlur, Bangalore, KA'

geolocator = Nominatim(user_agent='sunnypot1989@gmail.com')
location = geolocator.geocode(address)
type(location)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate are 12.9624669, 77.6381958.

# %%
address = 'Peenya, Bangalore, KA'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate are {}, {}.'.format(latitude, longitude))
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\envs\env1\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\envs\env1\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\envs\env1\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
CLIENT_ID = 'RINTZT52PZDA4WDXIRRRN3TMFC3NP1HDB1JEHQLOAS3XZVKV' # your Foursquare ID
CLIENT_SECRET = 'ITVDVFQAKKWKOLFYPPDT13FWYQMK3V3ZTZR4ZLBQQ21HWWHP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RINTZT52PZDA4WDXIRRRN3TMFC3NP1HDB1JEHQLOAS3XZVKV
# CLIENT_SECRET:ITVDVFQAKKWKOLFYPPDT13FWYQMK3V3ZTZR4ZLBQQ21HWWHP

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&near={}&radius={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            'Bangalor, India',
            13000)
            
        # make the GET request
#results = requests.get(url).json()["response"]['groups'][0]['items']

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bd836c19fb6b7529164343d'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'geocode': {'what': '',
#    'where': 'bangalor india',
#    'center': {'lat': 12.97194, 'lng': 77.59369},
#    'displayString': 'Bangalore, Karnātaka, India',
#    'cc': 'IN',
#    'geometry': {'bounds': {'ne': {'lat': 13.059007017435443,
#       'lng': 77.76335943244477},
#      'sw': {'lat': 12.90188996, 'lng': 77.50876188783272}}},
#    'slug': 'bangalore',
#    'longId': '72057594039205269'},
#   'headerLocation': 'Bangalore',
#   'headerFullLocation': 'Bangalore',
#   'headerLocationGranularity': 'city',
#   'totalResults': 237,
#   'suggestedBounds': {'ne': {'lat': 12.9881775302129,
#     'lng': 77.61215476334367},
#    'sw': {'lat': 12.965720506392378, 'lng': 77.58359475913907}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
# ...
