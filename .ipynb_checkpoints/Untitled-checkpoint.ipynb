# %%
from geopy.geocoders import Nominatim

# %%
import pandas as pd
import numpy as np
import requests

# %%
address = 'HSR Layout, Bangalore, KA'

geolocator = Nominatim(user_agent='sunnypot1989@gmail.com')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate are 12.9116225, 77.6388622.

# %%
address = 'Peenya, Bangalore, KA'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate are 13.0329419, 77.5273253.

# %%
CLIENT_ID = 'RINTZT52PZDA4WDXIRRRN3TMFC3NP1HDB1JEHQLOAS3XZVKV' # your Foursquare ID
CLIENT_SECRET = 'ITVDVFQAKKWKOLFYPPDT13FWYQMK3V3ZTZR4ZLBQQ21HWWHP' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RINTZT52PZDA4WDXIRRRN3TMFC3NP1HDB1JEHQLOAS3XZVKV
# CLIENT_SECRET:ITVDVFQAKKWKOLFYPPDT13FWYQMK3V3ZTZR4ZLBQQ21HWWHP

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            latitude,
            longitude,
            1500,200)
            
        # make the GET request
#results = requests.get(url).json()["response"]['groups'][0]['items']

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bd828e89fb6b75292394400'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 53,
#   'suggestedBounds': {'ne': {'lat': 12.925122513500014,
#     'lng': 77.65268654368904},
#    'sw': {'lat': 12.898122486499986, 'lng': 77.62503785631097}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57af3398498ee1bf30181d21',
#        'name': 'House of Commons',
#        'location': {'crossStreet': 'HSR layout',
#         'lat': 12.911993951538978,
#         'lng': 77.63893839495603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.911993951538978,
#           'lng': 77.63893839495603}],
#         'distance': 42,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR layout',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57af3398498ee1bf30181d21-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5523bea0498e6b7d10ba441a',
#        'name': 'Cream Stone',
#        'location': {'lat': 12.912336259572271,
#         'lng': 77.63858101632954,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912336259572271,
#           'lng': 77.63858101632954}],
#         'distance': 85,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5523bea0498e6b7d10ba441a-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57625d3b498e28a76b4d38e4',
#        'name': 'Here & Now',
#        'location': {'address': 'HSR, Opp BDA Complex',
#         'lat': 12.913617873412562,
#         'lng': 77.63824265968887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.913617873412562,
#           'lng': 77.63824265968887}],
#         'distance': 232,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['HSR, Opp BDA Complex', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57625d3b498e28a76b4d38e4-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54cb40e7498ecfa9d547cbed',
#        'name': 'Anjappar',
#        'location': {'address': 'Bda complex',
#         'crossStreet': 'HSR layout',
#         'lat': 12.914337555485753,
#         'lng': 77.63715891761294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.914337555485753,
#           'lng': 77.63715891761294}],
#         'distance': 354,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bda complex (HSR layout)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff2',
#          'name': 'Chettinad Restaurant',
#          'pluralName': 'Chettinad Restaurants',
#          'shortName': 'Chettinad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54cb40e7498ecfa9d547cbed-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5335ac3e498e1f27127ff01d',
#        'name': 'Earth Plate',
#        'location': {'address': '#1, Sector-7, HSR',
#         'crossStreet': '14th Main, 11th Cross',
#         'lat': 12.912395436186763,
#         'lng': 77.63827136316252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912395436186763,
#           'lng': 77.63827136316252}],
#         'distance': 107,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#1, Sector-7, HSR (14th Main, 11th Cross)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5335ac3e498e1f27127ff01d-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc0a5cb74a9a5932f59d0f6',
#        'name': 'The Punjabi Rasoi',
#        'location': {'address': '1082, 18th Cross',
#         'crossStreet': 'Sector 3, HSR Layout',
#         'lat': 12.911959008177734,
#         'lng': 77.63842481946776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.911959008177734,
#           'lng': 77.63842481946776}],
#         'distance': 60,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['1082, 18th Cross (Sector 3, HSR Layout)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff0',
#          'name': 'Punjabi Restaurant',
#          'pluralName': 'Punjabi Restaurants',
#          'shortName': 'Punjabi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc0a5cb74a9a5932f59d0f6-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '564606e4498e6fcc3ea2594f',
#        'name': 'Once Upon A Flame',
#        'location': {'address': 'HSR',
#         'lat': 12.91192776488194,
#         'lng': 77.63805414341695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.91192776488194,
#           'lng': 77.63805414341695}],
#         'distance': 94,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['HSR', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-564606e4498e6fcc3ea2594f-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50169a03e4b0e28d9a40a8df',
#        'name': 'Corner House',
#        'location': {'address': '#1666, HSR layout',
#         'crossStreet': 'Sector 2, HSR Layout, 27th Main Rd',
#         'lat': 12.909948588084937,
#         'lng': 77.65188251591857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.909948588084937,
#           'lng': 77.65188251591857}],
#         'distance': 1424,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#1666, HSR layout (Sector 2, HSR Layout, 27th Main Rd)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50169a03e4b0e28d9a40a8df-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5392d32b498eb409d6851d22',
#        'name': 'Calvins',
#        'location': {'address': 'Near BDA complex',
#         'crossStreet': 'HSR LAYOUT',
#         'lat': 12.912182357202179,
#         'lng': 77.6376609572448,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912182357202179,
#           'lng': 77.6376609572448}],
#         'distance': 144,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Near BDA complex (HSR LAYOUT)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5392d32b498eb409d6851d22-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574e526c498eda528c79cab1',
#        'name': 'Agara Lake Trail',
#        'location': {'lat': 12.916410222108041,
#         'lng': 77.63894110720983,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.916410222108041,
#           'lng': 77.63894110720983}],
#         'distance': 533,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574e526c498eda528c79cab1-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53bbe71b498e819e1e6acb8b',
#        'name': "Northam's Pizza Pita",
#        'location': {'lat': 12.908749,
#         'lng': 77.646835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.908749,
#           'lng': 77.646835}],
#         'distance': 922,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53bbe71b498e819e1e6acb8b-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572376b2498e96aa8e185481',
#        'name': 'Sector 7 Cafe',
#        'location': {'crossStreet': 'HSR Layout Sector - 7',
#         'lat': 12.912301721380308,
#         'lng': 77.63365801581732,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912301721380308,
#           'lng': 77.63365801581732}],
#         'distance': 569,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout Sector - 7',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572376b2498e96aa8e185481-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ecf98ad439072ceeb2e014',
#        'name': "Kapoor's Café",
#        'location': {'address': '324, 21st Cross Road',
#         'crossStreet': 'Hsr Layout 27th Main',
#         'lat': 12.907856548178044,
#         'lng': 77.65171154319802,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.907856548178044,
#           'lng': 77.65171154319802}],
#         'distance': 1455,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['324, 21st Cross Road (Hsr Layout 27th Main)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff0',
#          'name': 'Punjabi Restaurant',
#          'pluralName': 'Punjabi Restaurants',
#          'shortName': 'Punjabi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ecf98ad439072ceeb2e014-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57d52fab498e3a97a8f6d2e5',
#        'name': 'Grapevine',
#        'location': {'lat': 12.909401610261101,
#         'lng': 77.63816757885431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.909401610261101,
#           'lng': 77.63816757885431}],
#         'distance': 258,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore 560102', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57d52fab498e3a97a8f6d2e5-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c00b24b8c1076b0a19e2071',
#        'name': 'Juice Junction',
#        'location': {'address': '#2628',
#         'crossStreet': '27th Main Rd, 1st Sector, HSR Layout',
#         'lat': 12.915107444946734,
#         'lng': 77.65172854034313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.915107444946734,
#           'lng': 77.65172854034313}],
#         'distance': 1448,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#2628 (27th Main Rd, 1st Sector, HSR Layout)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c00b24b8c1076b0a19e2071-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '556c8e83498e9296ebefdc8a',
#        'name': 'Mughal Treat',
#        'location': {'address': '#1563',
#         'crossStreet': '27th Main, Opp KEB Power Station',
#         'lat': 12.90368049969952,
#         'lng': 77.64954191416928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.90368049969952,
#           'lng': 77.64954191416928}],
#         'distance': 1457,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#1563 (27th Main, Opp KEB Power Station)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d115941735',
#          'name': 'Middle Eastern Restaurant',
#          'pluralName': 'Middle Eastern Restaurants',
#          'shortName': 'Middle Eastern',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-556c8e83498e9296ebefdc8a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5323004c498ecdae903568b2',
#        'name': 'Art Blend Cafe',
#        'location': {'address': '#659, HSR 2nd sector',
#         'crossStreet': '22nd Cross, 24th Main',
#         'lat': 12.908900796279104,
#         'lng': 77.64777283762216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.908900796279104,
#           'lng': 77.64777283762216}],
#         'distance': 1013,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#659, HSR 2nd sector (22nd Cross, 24th Main)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5323004c498ecdae903568b2-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f10c69498efa20083bf229',
#        'name': 'Cafe Coffee Day',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.912312,
#         'lng': 77.641245,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912312,
#           'lng': 77.641245}],
#         'distance': 269,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f10c69498efa20083bf229-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da45ef0b3e7236a44ee4479',
#        'name': 'MK Ahmed Super Market',
#        'location': {'address': '58/59, Sector 6, 12th Main',
#         'crossStreet': '17th cross, HSR Layout',
#         'lat': 12.912461639989539,
#         'lng': 77.63671324617263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912461639989539,
#           'lng': 77.63671324617263}],
#         'distance': 251,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['58/59, Sector 6, 12th Main (17th cross, HSR Layout)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da45ef0b3e7236a44ee4479-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55620404498ef94ca8205f06',
#        'name': '49ParanthaGali',
#        'location': {'address': '14th main',
#         'crossStreet': '17th Cross, Sector 4 , Near HSR BDA Complex.',
#         'lat': 12.912309452984541,
#         'lng': 77.63856948157061,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912309452984541,
#           'lng': 77.63856948157061}],
#         'distance': 82,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['14th main (17th Cross, Sector 4 , Near HSR BDA Complex.)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfdd',
#          'name': 'North Indian Restaurant',
#          'pluralName': 'North Indian Restaurants',
#          'shortName': 'North Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55620404498ef94ca8205f06-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c0eca5498e9f69ab8a9c70',
#        'name': 'Biriyani Zone',
#        'location': {'lat': 12.920138333489826,
#         'lng': 77.64500385314999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.920138333489826,
#           'lng': 77.64500385314999}],
#         'distance': 1158,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe6',
#          'name': 'Hyderabadi Restaurant',
#          'pluralName': 'Hyderabadi Restaurants',
#          'shortName': 'Hyderabadi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c0eca5498e9f69ab8a9c70-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c613074924b76b0c936fab9',
#        'name': 'Café Coffee Day',
#        'location': {'address': 'RAMESH PLAZA - HSR LAYOUT,22.NO.144/ 150 RING ROAD',
#         'crossStreet': 'HSR Layout',
#         'lat': 12.909285707816219,
#         'lng': 77.63967275619507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.909285707816219,
#           'lng': 77.63967275619507}],
#         'distance': 274,
#         'postalCode': '560034',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['RAMESH PLAZA - HSR LAYOUT,22.NO.144/ 150 RING ROAD (HSR Layout)',
#          'Bangalore 560034',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c613074924b76b0c936fab9-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5537bc44498e1e89566bd342',
#        'name': 'Pappu Chai Walla',
#        'location': {'lat': 12.91311844081052,
#         'lng': 77.64461143949057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.91311844081052,
#           'lng': 77.64461143949057}],
#         'distance': 645,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5537bc44498e1e89566bd342-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523ea34f498e4da124789a89',
#        'name': 'Mumbai Tiffin',
#        'location': {'address': 'HSR layout',
#         'lat': 12.913404876416857,
#         'lng': 77.6445623279477,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.913404876416857,
#           'lng': 77.6445623279477}],
#         'distance': 649,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR layout', 'Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523ea34f498e4da124789a89-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f82957ce4b0ef209a28678b',
#        'name': 'Nandhini Cool Joint',
#        'location': {'address': 'Sector 2',
#         'lat': 12.91171280966049,
#         'lng': 77.64451250539756,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.91171280966049,
#           'lng': 77.64451250539756}],
#         'distance': 613,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Sector 2',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f82957ce4b0ef209a28678b-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ac2c2e498e73a1398dd13c',
#        'name': "Domino's Pizza",
#        'location': {'address': 'GROUND FLOOR, # 1573, SECTOR 1(AGARA), HSR LAYOUT,,BANGALORE - 560102 PH.NO. 080-25727781/ 84/ 25729683/ 84/ 85',
#         'lat': 12.912,
#         'lng': 77.645,
#         'labeledLatLngs': [{'label': 'display', 'lat': 12.912, 'lng': 77.645}],
#         'distance': 667,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['GROUND FLOOR, # 1573, SECTOR 1(AGARA), HSR LAYOUT,,BANGALORE - 560102 PH.NO. 080-25727781/ 84/ 25729683/ 84/ 85',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ac2c2e498e73a1398dd13c-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53805253498e1f5b4247b87d',
#        'name': 'Napoli',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.916351198074109,
#         'lng': 77.65174251058956,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.916351198074109,
#           'lng': 77.65174251058956}],
#         'distance': 1493,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout', 'Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53805253498e1f5b4247b87d-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9773a282b56dcbd2d0e9aa',
#        'name': 'Luo Han',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.916021231379883,
#         'lng': 77.65153131684445,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.916021231379883,
#           'lng': 77.65153131684445}],
#         'distance': 1459,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout', 'Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9773a282b56dcbd2d0e9aa-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5103d9d3e4b022bff93870fb',
#        'name': 'Gold Bean',
#        'location': {'address': 'Near BDA Complex',
#         'crossStreet': 'HSR Layout',
#         'lat': 12.912273478307078,
#         'lng': 77.64085435241307,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912273478307078,
#           'lng': 77.64085435241307}],
#         'distance': 227,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Near BDA Complex (HSR Layout)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5103d9d3e4b022bff93870fb-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519f977e498e0b1f0d45b6cd',
#        'name': 'Vasudev Adigas',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.911720096884176,
#         'lng': 77.63245035213414,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.911720096884176,
#           'lng': 77.63245035213414}],
#         'distance': 695,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-519f977e498e0b1f0d45b6cd-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51449d64e4b00b9d256f5ef5',
#        'name': 'Adyar Ananda Bhavan',
#        'location': {'address': 'No.27, HSR BDA Complex',
#         'lat': 12.913715219870335,
#         'lng': 77.63747899676768,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.913715219870335,
#           'lng': 77.63747899676768}],
#         'distance': 277,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['No.27, HSR BDA Complex',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51449d64e4b00b9d256f5ef5-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c39653fae2da593919202c6',
#        'name': 'M K Retail',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.911946541450927,
#         'lng': 77.65124087365119,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.911946541450927,
#           'lng': 77.65124087365119}],
#         'distance': 1343,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c39653fae2da593919202c6-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5204f050498ee4fd3cf79b5c',
#        'name': 'Bangalore Agarwal Bhavan',
#        'location': {'address': 'HSR Layout',
#         'lat': 12.913228596735953,
#         'lng': 77.63526425747744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.913228596735953,
#           'lng': 77.63526425747744}],
#         'distance': 429,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['HSR Layout', 'Bangalore', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5204f050498ee4fd3cf79b5c-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e691a6e4b038bec2f65897',
#        'name': "The Moghul's",
#        'location': {'address': '447, 17th Cross, 17th Main, HSR Layout Sector 4',
#         'lat': 12.91228533379858,
#         'lng': 77.64207017111667,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.91228533379858,
#           'lng': 77.64207017111667}],
#         'distance': 355,
#         'postalCode': '560034',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['447, 17th Cross, 17th Main, HSR Layout Sector 4',
#          'Bangalore 560034',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50e691a6e4b038bec2f65897-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '538adbae498e18191854b75d',
#        'name': 'Purnabramha Maharashtrian Restaurant',
#        'location': {'address': 'Hsr Layout',
#         'lat': 12.912537057400575,
#         'lng': 77.64457140138857,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912537057400575,
#           'lng': 77.64457140138857}],
#         'distance': 627,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['Hsr Layout', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-538adbae498e18191854b75d-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc6d316b2beb1f7347b2a4c',
#        'name': 'Latte',
#        'location': {'lat': 12.910233506394173,
#         'lng': 77.65204995249523,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.910233506394173,
#           'lng': 77.65204995249523}],
#         'distance': 1439,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc6d316b2beb1f7347b2a4c-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7896fd9e57a0937726c62b',
#        'name': 'Grigliato',
#        'location': {'address': '1562 1st Sector',
#         'lat': 12.922213884868034,
#         'lng': 77.64535731670367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.922213884868034,
#           'lng': 77.64535731670367}],
#         'distance': 1373,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['1562 1st Sector',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7896fd9e57a0937726c62b-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56614d16498e897cba8f473c',
#        'name': "Domino's Pizza",
#        'location': {'lat': 12.912907275376886,
#         'lng': 77.65180874466108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912907275376886,
#           'lng': 77.65180874466108}],
#         'distance': 1412,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56614d16498e897cba8f473c-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb45d3a39458cfaf91c20a0',
#        'name': 'Shubh',
#        'location': {'address': '27th Main Road',
#         'crossStreet': 'HSR Layout',
#         'lat': 12.9138288571892,
#         'lng': 77.65178099928832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.9138288571892,
#           'lng': 77.65178099928832}],
#         'distance': 1423,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['27th Main Road (HSR Layout)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb45d3a39458cfaf91c20a0-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a64831e4b00184ad823297',
#        'name': 'Sichuan',
#        'location': {'address': '#1552, 19th Main Road, Opp IOL Petrol Bunk',
#         'crossStreet': 'HSR Layout, Sector -1',
#         'lat': 12.92100331745828,
#         'lng': 77.64514299541143,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.92100331745828,
#           'lng': 77.64514299541143}],
#         'distance': 1246,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#1552, 19th Main Road, Opp IOL Petrol Bunk (HSR Layout, Sector -1)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a64831e4b00184ad823297-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf09e721d18a143f0f74dec',
#        'name': 'Pizza Hut',
#        'location': {'address': '2633, 27th Main, 13th Cross Rd',
#         'crossStreet': 'Sector 1, HSR Layout',
#         'lat': 12.915793325011952,
#         'lng': 77.65160180579932,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.915793325011952,
#           'lng': 77.65160180579932}],
#         'distance': 1458,
#         'postalCode': '560102',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['2633, 27th Main, 13th Cross Rd (Sector 1, HSR Layout)',
#          'Bangalore 560102',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf09e721d18a143f0f74dec-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df4f14145dd4e2693459d36',
#        'name': 'Sardarji ka dhaba',
#        'location': {'address': 'Central Silk board',
#         'lat': 12.912220609260222,
#         'lng': 77.62611185077701,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.912220609260222,
#           'lng': 77.62611185077701}],
#         'distance': 1385,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Central Silk board',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df4f14145dd4e2693459d36-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd85275e4b00148b90c7b2d',
#        'name': 'Hotel Ibis',
#        'location': {'address': '26/1, Near Central Silk Board Junction, next to Oxford College of Engineering',
#         'crossStreet': 'Hosur Road',
#         'lat': 12.901014773407669,
#         'lng': 77.63212547314244,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.901014773407669,
#           'lng': 77.63212547314244}],
#         'distance': 1388,
#         'postalCode': '560068',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['26/1, Near Central Silk Board Junction, next to Oxford College of Engineering (Hosur Road)',
#          'Bangalore 560068',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd85275e4b00148b90c7b2d-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0fc27898102d7f41bee506',
#        'name': "Nanda's",
#        'location': {'address': '#1558, Ring Road, 19th Main,',
#         'crossStreet': 'HSR Sector 1',
#         'lat': 12.92182371957422,
#         'lng': 77.64496964525961,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.92182371957422,
#           'lng': 77.64496964525961}],
#         'distance': 1314,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['#1558, Ring Road, 19th Main, (HSR Sector 1)',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0fc27898102d7f41bee506-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5728d985498e8054a6c89167',
#        'name': 'Zero Mile Punjab',
#        'location': {'lat': 12.916699,
#         'lng': 77.63039,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.916699,
#           'lng': 77.63039}],
#         'distance': 1079,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dff0',
#          'name': 'Punjabi Restaurant',
#          'pluralName': 'Punjabi Restaurants',
#          'shortName': 'Punjabi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5728d985498e8054a6c89167-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f586efee4b0db97b70eed55',
#        'name': 'Fooday kabab center',
#        'location': {'lat': 12.905932870493457,
#         'lng': 77.62922778642283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.905932870493457,
#           'lng': 77.62922778642283}],
#         'distance': 1222,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f586efee4b0db97b70eed55-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da30b29d0f541bd64f5648e',
#        'name': 'Pepe Jeans London',
#        'location': {'address': 'TOTAL Mall, Madivala, Hosur Road',
#         'lat': 12.906063396436238,
#         'lng': 77.6290991229256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.906063396436238,
#           'lng': 77.6290991229256}],
#         'distance': 1226,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['TOTAL Mall, Madivala, Hosur Road',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da30b29d0f541bd64f5648e-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8749e06c2579c39cc7e6a0',
#        'name': 'Ajeet Punjabi Food',
#        'location': {'address': "#4, 13th Cross, Teachers' Colony Main Road",
#         'crossStreet': 'Venkatapura, 1st Block, Koramangala',
#         'lat': 12.919163524172005,
#         'lng': 77.62980397332188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.919163524172005,
#           'lng': 77.62980397332188}],
#         'distance': 1292,
#         'postalCode': '560034',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ["#4, 13th Cross, Teachers' Colony Main Road (Venkatapura, 1st Block, Koramangala)",
#          'Bangalore 560034',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8749e06c2579c39cc7e6a0-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f5616ffe4b05b4bc3e83239',
#        'name': 'Priya Bakery',
#        'location': {'lat': 12.919231408338682,
#         'lng': 77.62962909607266,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.919231408338682,
#           'lng': 77.62962909607266}],
#         'distance': 1311,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f5616ffe4b05b4bc3e83239-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '522abd7811d20dc0b1ab42e2',
#        'name': 'Park',
#        'location': {'address': 'Teachers Colony',
#         'lat': 12.91922876847344,
#         'lng': 77.62961771257552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.91922876847344,
#           'lng': 77.62961771257552}],
#         'distance': 1312,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Teachers Colony',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-522abd7811d20dc0b1ab42e2-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50db2964e4b047bb20217c70',
#        'name': 'New Sagar Veg & Non-Veg Restaurant',
#        'location': {'address': '8th Cross, VENKATAPURA, Koramangala 1st Block',
#         'lat': 12.919246969658367,
#         'lng': 77.62962084217942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.919246969658367,
#           'lng': 77.62962084217942}],
#         'distance': 1313,
#         'postalCode': '560034',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['8th Cross, VENKATAPURA, Koramangala 1st Block',
#          'Bangalore 560034',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50db2964e4b047bb20217c70-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db1beae8154905aadc7cbf1',
#        'name': 'Roopena Agrahara',
#        'location': {'lat': 12.911401036128554,
#         'lng': 77.62650903947525,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.911401036128554,
#           'lng': 77.62650903947525}],
#         'distance': 1340,
#         'postalCode': '560068',
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Bangalore 560068', 'Karnātaka', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db1beae8154905aadc7cbf1-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a11499e4b094dc65049c22',
#        'name': 'Vishal Mega mart',
#        'location': {'address': 'Roopenagraha',
#         'lat': 12.913134327336678,
#         'lng': 77.62536781746928,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 12.913134327336678,
#           'lng': 77.62536781746928}],
#         'distance': 1473,
#         'cc': 'IN',
#         'city': 'Bangalore',
#         'state': 'Karnātaka',
#         'country': 'India',
#         'formattedAddress': ['Roopenagraha',
#          'Bangalore',
#          'Karnātaka',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a11499e4b094dc65049c22-52'}]}]}}
